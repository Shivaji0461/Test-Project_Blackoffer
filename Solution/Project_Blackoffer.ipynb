# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install contractions

# %%
# !pip install newspaper3k

# %%
# Import Essential libraries

import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
import contractions
from newspaper import Article
import nltk
from collections import  Counter
from textblob import TextBlob
import numpy as np

# %%
# Import the URL dataset

# pd.set_option('display.max_colwidth',200)
data = pd.read_excel('Input.xlsx')
data.head()
# Out:
#    URL_ID                                                URL
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...

# %%
# Removed 3nos. url because they have found error
data = data.loc[data.index.drop([7,20,107])]
data = data.reset_index(drop=True)
data.head()
# Out:
#    URL_ID                                                URL
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...

# %%
# Extract the article text and article title.
def get_text(url):
    url1 = url
    article = Article(url1,language='en')
    article.download()
    article.parse()
    article.nlp()
    return article.text

# %%
for i in range(len(data)):
    data['URL_ID'][i] = get_text(data['URL'][i])

data.head()
# Out:
#                                               URL_ID  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...

# %%
data = data.rename(columns={'URL_ID':'text'})
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...

# %% [markdown]
# # 1. Sentimental Analysis

# %% [markdown]
# # 1.1. Cleaning using Stop Words Lists

# %%
# Import the stopword dataset

stop_1 = pd.read_csv('StopWords_Auditor.txt',header=None)
stop_2 = pd.read_csv('StopWords_Currencies.txt',header=None,sep='delimeter',encoding="ISO-8859-1")
stop_3 = pd.read_csv('StopWords_DatesandNumbers.txt',header=None)
stop_4 = pd.read_csv('StopWords_Generic.txt',header=None)
stop_5 = pd.read_csv('StopWords_GenericLong.txt',header=None)
stop_6 = pd.read_csv('StopWords_Geographic.txt',header=None)
stop_7 = pd.read_csv('StopWords_Names.txt',header=None)

stop_words = pd.concat([stop_1,stop_2,stop_3,stop_4,stop_5,stop_6,stop_7])
stop_words = stop_words.iloc[:, 0].tolist()

print(stop_words)
# Out:
# ['ERNST', 'YOUNG', 'DELOITTE', 'TOUCHE', 'KPMG', 'PRICEWATERHOUSECOOPERS', 'PRICEWATERHOUSE', 'COOPERS', 'AFGHANI  | Afghanistan', 'ARIARY | Madagascar', 'BAHT | Thailand', 'BALBOA | Panama', 'BIRR | Ethiopia', 'BOLIVAR | Venezuela', 'BOLIVIANO  | Bolivia', 'CEDI | Ghana', 'COLON  | Costa Rica', 'CÓRDOBA  | Nicaragua', 'DALASI | Gambia', 'DENAR | Macedonia (Former Yug. Rep.)', 'DINAR | Algeria', 'DIRHAM  | Morocco', 'DOBRA | São Tom and Príncipe', 'DONG | Vietnam', 'DRAM | Armenia', 'ESCUDO  | Cape Verde', 'EURO  | Belgium', 'FLORIN | Aruba', 'FORINT | Hungary', 'GOURDE | Haiti', 'GUARANI | Paraguay', 'GULDEN | Netherlands Antilles', 'HRYVNIA  | Ukraine', 'KINA | Papua New Guinea', 'KIP | Laos', 'KONVERTIBILNA MARKA  | Bosnia-Herzegovina', 'KORUNA  | Czech Republic', 'KRONA | Sweden', 'KRONE | Denmark', 'KROON | Estonia', 'KUNA | Croatia', 'KWACHA | Zambia', 'KWANZA | Angola', 'KYAT | Myanmar', 'LARI | Georgia', 'LATS | Latvia', 'LEK | Albania', 'LEMPIRA | Honduras', 'LEONE | Sierra Leone', 'LEU | Romania', 'LEV | Bulgaria', 'LILANGENI  | Swaziland', 'LIRA | Lebanon', 'LITAS | Lithuania', 'LOTI | Lesotho', 'MANAT | Azerbaijan', 'METICAL | Mozambique', 'NAIRA | Nigeria', 'NAKFA | Eritrea', 'NEW LIRA | Turkey', 'NEW SHEQEL  | Israel', 'NGULTRUM  | Bhutan', 'NUEVO SOL | Peru', 'OUGUIYA  | Mauritania', 'PATACA | Macau', 'PESO  | Mexico', 'POUND  | Egypt', 'PULA  | Botswana', 'QUETZAL | Guatemala', 'RAND | South Africa', 'REAL  | Brazil', 'RENMINBI  | China', 'RIAL | Iran', 'RIEL | Cambodia', 'RINGGIT | Malaysia', 'RIYAL | Saudi Arabia', 'RUBLE | Russia', 'RUFIYAA | Maldives', 'RUPEE  | India', 'RUPEE  | Pakistan', 'RUPIAH  | Indonesia', 'SHILLING  | Uganda', 'SOM | Uzbekistan', 'SOMONI  | Tajikistan', 'SPECIAL DRAWING RIGHTS  | International Monetary Fund', 'TAKA | Bangladesh', 'TALA | Western Samoa', 'TENGE | Kazakhstan', 'TUGRIK  | Mongolia', 'VATU | Vanuatu', 'WON  | Korea, South', 'YEN | Japan', 'ZLOTY | Poland', 'HUNDRED  | Denominations', 'THOUSAND', 'MILLION', 'BILLION', 'TRILLION', 'DATE  | Time related', 'ANNUAL', 'ANNUALLY', 'ANNUM', 'YEAR', 'YEARLY', 'QUARTER', 'QUARTERLY', 'QTR', 'MONTH', 'MONTHLY', 'WEEK', 'WEEKLY', 'DAY', 'DAILY', 'JANUARY  | Calendar', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY', 'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVEMBER', 'DECEMBER', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'SEPT', 'OCT', 'NOV', 'DEC', 'MONDAY', 'TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY', 'ONE  | Numbers', 'TWO', 'THREE', 'FOUR', 'FIVE', 'SIX', 'SEVEN', 'EIGHT', 'NINE', 'TEN', 'ELEVEN', 'TWELVE', 'THIRTEEN', 'FOURTEEN', 'FIFTEEN', 'SIXTEEN', 'SEVENTEEN', 'EIGHTEEN', 'NINETEEN', 'TWENTY', 'THIRTY', 'FORTY', 'FIFTY', 'SIXTY', 'SEVENTY', 'EIGHTY', 'NINETY', 'FIRST', 'SECOND', 'THIRD', 'FOURTH', 'FIFTH', 'SIXTH', 'SEVENTH', 'EIGHTH', 'NINTH', 'TENTH', 'I  | Roman numerals', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X', 'XI', 'XII', 'XIII', 'XIV', 'XV', 'XVI', 'XVII', 'XVIII', 'XIX', 'XX', 'ABOUT', 'ABOVE', 'AFTER', 'AGAIN', 'ALL', 'AM', 'AMONG', 'AN', 'AND', 'ANY', 'ARE', 'AS', 'AT', 'BE', 'BECAUSE', 'BEEN', 'BEFORE', 'BEING', 'BELOW', 'BETWEEN', 'BOTH', 'BUT', 'BY', 'CAN', 'DID', 'DO', 'DOES', 'DOING', 'DOWN', 'DURING', 'EACH', 'FEW', 'FOR', 'FROM', 'FURTHER', 'HAD', 'HAS', 'HAVE', 'HAVING', 'HE', 'HER', 'HERE', 'HERS', 'HERSELF', 'HIM', 'HIMSELF', 'HIS', 'HOW', 'IF', 'IN', 'INTO', 'IS', 'IT', 'ITS', 'ITSELF', 'JUST', 'ME', 'MORE', 'MOST', 'MY', 'MYSELF', 'NO', 'NOR', 'NOT', 'NOW', 'OF', 'OFF', 'ON', 'ONCE', 'ONLY', 'OR', 'OTHER', 'OUR', 'OURS', 'OURSELVES', 'OUT', 'OVER', 'OWN', 'SAME', 'SHE', 'SHOULD', 'SO', 'SOME', 'SUCH', 'THAN', 'THAT', 'THE', 'THEIR', 'THEIRS', 'THEM', 'THEMSELVES', 'THEN', 'THERE', 'THESE', 'THEY', 'THIS', 'THOSE', 'THROUGH', 'TO', 'TOO', 'UNDER', 'UNTIL', 'UP', 'VERY', 'WAS', 'WE', 'WERE', 'WHAT', 'WHEN', 'WHERE', 'WHICH', 'WHILE', 'WHO', 'WHOM', 'WHY', 'WITH', 'YOU', 'YOUR', 'YOURS', 'YOURSELF', 'YOURSELVES', 'a', "a's", 'able', 'about', 'above ...

# %%
# Text preprocessing stopword dataset

remove_url = re.sub('[^ ]+\.[^ ]+',' ', str(stop_words))

review_contraction = []   
for word in remove_url:
    (review_contraction.append(contractions.fix(word)))
review_contraction = ''.join(review_contraction)

text_preprocess = re.sub(r'[^\w\s]','',review_contraction)
digits = ''.join([re.sub('\S*\d\S*',' ',term) for term in text_preprocess])
extra_spaces = re.sub('\s\s+',' ',digits)
stop_words = [token.lower() for token in word_tokenize(digits)]

print(stop_words)
# Out:
# ['ernst', 'yoyoung', 'deloitte', 'toyouche', 'kpmg', 'pricewaterhoyousecoopers', 'pricewaterhoyouse', 'coopers', 'afghani', 'afghanistan', 'ariary', 'madagascar', 'baht', 'thailand', 'balboa', 'panama', 'birr', 'ethiopia', 'bolivar', 'venezyouela', 'boliviano', 'bolivia', 'cedi', 'ghana', 'colon', 'costa', 'rica', 'córdoba', 'nicaragyoua', 'dalasi', 'gambia', 'denar', 'macedonia', 'former', 'yyoug', 'dinar', 'algeria', 'dirham', 'morocco', 'dobra', 'são', 'tom', 'and', 'príncipe', 'dong', 'vietnam', 'dram', 'armenia', 'escyoudo', 'cape', 'verde', 'eyouro', 'belgiyoum', 'florin', 'aryouba', 'forint', 'hyoungary', 'goyourde', 'haiti', 'gyouarani', 'paragyouay', 'gyoulden', 'netherlands', 'antilles', 'hryvnia', 'youkraine', 'kina', 'papyoua', 'new', 'gyouinea', 'kip', 'laos', 'konvertibilna', 'marka', 'bosniaherzegovina', 'koryouna', 'czech', 'repyoublic', 'krona', 'sweden', 'krone', 'denmark', 'kroon', 'estonia', 'kyouna', 'croatia', 'kwacha', 'zambia', 'kwanza', 'angola', 'kyat', 'myanmar', 'lari', 'georgia', 'lats', 'latvia', 'lek', 'albania', 'lempira', 'hondyouras', 'leone', 'sierra', 'leone', 'leyou', 'romania', 'lev', 'byoulgaria', 'lilangeni', 'swaziland', 'lira', 'lebanon', 'litas', 'lithyouania', 'loti', 'lesotho', 'manat', 'azerbaijan', 'metical', 'mozambiqyoue', 'naira', 'nigeria', 'nakfa', 'eritrea', 'new', 'lira', 'tyourkey', 'new', 'sheqel', 'israel', 'ngyoultryoum', 'bhyoutan', 'nyouevo', 'sol', 'peryou', 'oyougyouiya', 'mayouritania', 'pataca', 'macayou', 'peso', 'mexico', 'poyound', 'egypt', 'pyoula', 'botswana', 'qyouetzal', 'gyouatemala', 'rand', 'soyouth', 'africa', 'real', 'brazil', 'renminbi', 'china', 'rial', 'iran', 'riel', 'cambodia', 'ringgit', 'malaysia', 'riyal', 'sayoudi', 'arabia', 'ryouble', 'ryoussia', 'ryoufiyaa', 'maldives', 'ryoupee', 'india', 'ryoupee', 'pakistan', 'ryoupiah', 'indonesia', 'shilling', 'youganda', 'som', 'youzbekistan', 'somoni', 'tajikistan', 'special', 'drawing', 'rights', 'international', 'monetary', 'fyound', 'taka', 'bangladesh', 'tala', 'western', 'samoa', 'tenge', 'kazakhstan', 'tyougrik', 'mongolia', 'vatyou', 'vanyouatyou', 'won', 'korea', 'soyouth', 'yen', 'japan', 'zloty', 'poland', 'hyoundred', 'denominations', 'thoyousand', 'million', 'billion', 'trillion', 'date', 'time', 'related', 'annyoual', 'annyoually', 'annyoum', 'year', 'yearly', 'qyouarter', 'qyouarterly', 'qtr', 'month', 'monthly', 'week', 'weekly', 'day', 'daily', 'janyouary', 'calendar', 'febryouary', 'march', 'april', 'may', 'jyoune', 'jyouly', 'ayougyoust', 'september', 'october', 'november', 'december', 'jan', 'feb', 'mar', 'apr', 'may', 'jyoun', 'jyoul', 'ayoug', 'sep', 'sept', 'oct', 'nov', 'dec', 'monday', 'tyouesday', 'wednesday', 'thyoursday', 'friday', 'satyourday', 'syounday', 'one', 'nyoumbers', 'two', 'three', 'foyour', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'eleven', 'twelve', 'thirteen', 'foyourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen', 'nineteen', 'twenty', 'thirty', 'forty', 'fifty', 'sixty', 'seventy', 'eighty', 'ninety', 'first', 'second', 'third', 'foyourth', 'fifth', 'sixth', 'seventh', 'eighth', 'ninth', 'tenth', 'i', 'roman', 'nyoumerals', 'ii', 'iii', 'iv', 'v', 'vi', 'vii', 'viii', 'ix', 'x', 'xi', 'xii', 'xiii', 'xiv', 'xv', 'xvi', 'xvii', 'xviii', 'xix', 'xx', 'aboyout', 'above', 'after', 'again', 'all', 'am', 'among', 'an', 'and', 'any', 'are', 'as', 'at', 'be', 'becayouse', 'been', 'before', 'being', 'below', 'between', 'both', 'byout', 'by', 'can', 'did', 'do', 'does', 'doing', 'down', 'dyouring', 'each', 'few', 'for', 'from', 'fyourther', 'had', 'has', 'have', 'having', 'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'if', 'in', 'into', 'is', 'it', 'its', 'itself', 'jyoust', 'me', 'more', 'most', 'my', 'myself', 'no', 'nor', 'not', 'now', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'oyour', 'oyours', 'oyourselves', 'oyout', 'over', 'own', 'same', 'she', 'shoyould', 'so', 'some', 'syouch', 'than', 'that', 'the', 'their', 'the ...

# %%
# Preprocessing on article text dataset
def Text_Preprocessing(text):
    content = re.sub(r'[^\w\s]','',text)
    digits = ''.join([re.sub('\S*\d\S*',' ',term) for term in content])
    extra_spaces = re.sub('\s\s+',' ',digits)
    tokens = [token.lower() for token in word_tokenize(extra_spaces)]
    non_stopwords = [word for word in tokens if word not in stop_words]
    return non_stopwords

# %%
data['preprocess_text'] = data['text'].apply(Text_Preprocessing)
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text
# 0  [introduction, kills, people, decades, highly,...
# 1  [human, minds, fascination, carrying, potentia...
# 2  [introduction, rapidly, evolving, employment, ...
# 3  [could, give, rise, smarterthanhuman, intellig...
# 4  [machine, intelligence, invention, humanity, m...

# %% [markdown]
# ## 1.2. Creating a dictionary of Positive and Negative words

# %%
with open('positive-words.txt') as pos:
    posswords = pos.read().split('\n')
posswords = ' ' .join(posswords)

# %%
with open('negative-words.txt',encoding="ISO-8859-1") as neg:
        negwords = neg.read().split('\n')

# %% [markdown]
# ## 1.3. Extracting Derived variables

# %% [markdown]
# ### 1. POSITIVE SCORE

# %%
def positive_text(text):
  pos_count = ' '.join([word for word in text if word in posswords])
  pos_count = pos_count.split(' ')
  positive_score = len(pos_count)
  return positive_score

# %%
data['POSITIVE SCORE'] = data['preprocess_text'].apply(positive_text)
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169

# %% [markdown]
# ### 2. NEGATIVE SCORE

# %%
def negative_text(text):
  neg_count = ' '.join([word for word in text if word in negwords])
  neg_count = neg_count.split(' ')
  positive_score = len(neg_count)
  return positive_score

# %%
data['NEGATIVE SCORE'] = data['preprocess_text'].apply(negative_text)
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE
# 0              34
# 1              37
# 2              36
# 3              28
# 4              28

# %% [markdown]
# ### 3. POLARITY SCORE

# %% [markdown]
# This is the score that determines if a given text is positive or negative in nature. It is calculated by using the formula:
# Polarity Score = (Positive Score – Negative Score)/ ((Positive Score + Negative Score) + 0.000001)
#
# Range is from -1 to +1

# %%
def polarity(text):
  sentiment = TextBlob(text).sentiment
  polarity = sentiment.polarity
  return polarity

# %%
data['POLARITY SCORE'] = np.nan

for i in range(len(data)):
    data['POLARITY SCORE'][i] = (data['POSITIVE SCORE'][i]-data['NEGATIVE SCORE'][i])/ ((data['POSITIVE SCORE'][i] + data['NEGATIVE SCORE'][i]) + 0.000001)

# %%
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE
# 0              34        0.626374
# 1              37        0.606383
# 2              36        0.588571
# 3              28        0.763713
# 4              28        0.715736

# %% [markdown]
# ### 4. SUBJECTIVITY SCORE

# %% [markdown]
# This is the score that determines if a given text is objective or subjective. It is calculated by using TextBlob library.
#
# Range is from 0 to +1

# %%
data['SUBJECTIVITY SCORE'] = np.nan

for i in range(len(data)):
    data['SUBJECTIVITY SCORE'][i] = TextBlob(str(data['preprocess_text'][i])).sentiment[1]
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE
# 0              34        0.626374            0.456853
# 1              37        0.606383            0.410712
# 2              36        0.588571            0.513278
# 3              28        0.763713            0.464118
# 4              28        0.715736            0.528261

# %%
data['WORD COUNT'] = data['preprocess_text'].apply(lambda x: len(x))
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803

# %% [markdown]
# # 2. Analysis of Readability

# %% [markdown]
# Analysis of Readability is calculated using the Gunning Fox index formula described below.
#
# Average Sentence Length = the number of words / the number of sentences
#
# Percentage of Complex words = the number of complex words / the number of words
#
# Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)

# %%
data['AVG SENTENCE LENGTH'] = np.nan
for i in range(len(data)):
  data['AVG SENTENCE LENGTH'][i] = data['WORD COUNT'][i] / len(sent_tokenize(str(data['text'][i])))

# %%
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH
# 0            13.064935
# 1             7.325000
# 2            10.082353
# 3             7.305263
# 4            10.164557

# %% [markdown]
# # 3. Average Number of Words Per Sentence

# %% [markdown]
# The formula for calculating is:
#
# Average Number of Words Per Sentence = the total number of words / the total number of sentences

# %%
data['AVG NUMBER OF WORDS PER SENTENCE'] = np.nan
for i in range(len(data)):
  data['AVG NUMBER OF WORDS PER SENTENCE'][i] = round(data['WORD COUNT'][i] / len(sent_tokenize(str(data['text'][i]))),2)

# %%
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH  AVG NUMBER OF WORDS PER SENTENCE
# 0            13.064935                             13.06
# 1             7.325000                              7.32
# 2            10.082353                             10.08
# 3             7.305263                              7.31
# 4            10.164557                             10.16

# %% [markdown]
# # 4. Complex Word Count
# Complex words are words in the text that contain more than two syllables.

# %%
def complex_word_count(x):
    
    syllable = 'aeiou'
    
    t = x
    
    v = []
    
    for i in t:
        words = i
        c=Counter()
        
        for word in words:
            c.update(set(word))

        n = 0
        for a in c.most_common():
            if a[0] in syllable:
                if a[1] >= 2:
                    n += 1
                
        m = 0
        p = []
        for a in c.most_common():
            if a[0] in syllable:
                p.append(a[0])
        if len(p) >= 2:
            m += 1
        
        if n >= 1 or m >= 1:
            v.append(i)
            
    return len(v)

# %%
data['COMPLEX WORD COUNT'] = np.nan

data['COMPLEX WORD COUNT'] = data['preprocess_text'].apply(lambda x: complex_word_count(x))
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT
# 0            13.064935                             13.06                 911
# 1             7.325000                              7.32                 476
# 2            10.082353                             10.08                 783
# 3             7.305263                              7.31                 591
# 4            10.164557                             10.16                 687

# %%
data['PERCENTAGE OF COMPLEX WORDS'] = np.nan

for i in range(len(data)):
  data['PERCENTAGE OF COMPLEX WORDS'][i] = data['COMPLEX WORD COUNT'][i] / data['WORD COUNT'][i]
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  \
# 0            13.064935                             13.06                 911
# 1             7.325000                              7.32                 476
# 2            10.082353                             10.08                 783
# 3             7.305263                              7.31                 591
# 4            10.164557                             10.16                 687
#
#    PERCENTAGE OF COMPLEX WORDS
# 0                     0.905567
# 1                     0.812287
# 2                     0.913652
# 3                     0.851585
# 4                     0.855542

# %%
data['FOG INDEX'] = np.nan

for i in range(len(data)):
  data['FOG INDEX'][i] = 0.4 * (data['AVG NUMBER OF WORDS PER SENTENCE'][i] + data['PERCENTAGE OF COMPLEX WORDS'][i])
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  \
# 0            13.064935                             13.06                 911
# 1             7.325000                              7.32                 476
# 2            10.082353                             10.08                 783
# 3             7.305263                              7.31                 591
# 4            10.164557                             10.16                 687
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX
# 0                     0.905567   5.586227
# 1                     0.812287   3.252915
# 2                     0.913652   4.397461
# 3                     0.851585   3.264634
# 4                     0.855542   4.406217

# %% [markdown]
# # 6 Syllable Count Per Word
# We count the number of Syllables in each word of the text by counting the vowels present in each word. We also handle some exceptions like words ending with "es","ed" by not counting them as a syllable.

# %%
def syllable_count(word):
    word = word.lower()
    count = 0
    vowels = "aeiouy"
    if word[0] in vowels:
        count += 1
    for index in range(1, len(word)):
        if word[index] in vowels and word[index - 1] not in vowels:
            count += 1
    if word.endswith("e"):
        count -= 1
    if count == 0:
        count += 1
    return count

# %%
data['SYLLABLE PER WORD'] = np.nan
for i in range(len(data)):
  data['SYLLABLE PER WORD'][i] = syllable_count(''.join(data['preprocess_text'][i]))

data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  \
# 0            13.064935                             13.06                 911
# 1             7.325000                              7.32                 476
# 2            10.082353                             10.08                 783
# 3             7.305263                              7.31                 591
# 4            10.164557                             10.16                 687
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  SYLLABLE PER WORD
# 0                     0.905567   5.586227             2583.0
# 1                     0.812287   3.252915             1381.0
# 2                     0.913652   4.397461             2254.0
# 3                     0.851585   3.264634             1652.0
# 4                     0.855542   4.406217             1964.0

# %% [markdown]
# # 7. Personal Pronouns
# To calculate Personal Pronouns mentioned in the text, we use regex to find the counts of the words - “I,” “we,” “my,” “ours,” and “us”. Special care is taken so that the country name US is not included in the list.

# %%
def ProperNoun(text):
    count = 0
    text = ' '.join(text)
    sentences = sent_tokenize(text)
    for sentence in sentences:
        words = word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        for word, tag in tagged:
            if tag == 'PRP':
                count = count + 1
        return count

# %%
data['PERSONAL PRONOUNS'] = data['preprocess_text'].apply(ProperNoun)

# %%
data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  \
# 0            13.064935                             13.06                 911
# 1             7.325000                              7.32                 476
# 2            10.082353                             10.08                 783
# 3             7.305263                              7.31                 591
# 4            10.164557                             10.16                 687
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  SYLLABLE PER WORD  \
# 0                     0.905567   5.586227             2583.0
# 1                     0.812287   3.252915             1381.0
# 2                     0.913652   4.397461             2254.0
# 3                     0.851585   3.264634             1652.0
# 4                     0.855542   4.406217             1964.0
#
#    PERSONAL PRONOUNS
# 0                  1
# 1                  5
# 2                  2
# 3                  3
# 4                  8

# %% [markdown]
# # 8. Average Word Length
# Average Word Length is calculated by the formula:
#
# Sum of the total number of characters in each word/Total number of words

# %%
data['AVG WORD LENGTH'] =  np.nan

for i in range(len(data)):
  data['AVG WORD LENGTH'][i] = round(len(''.join(data['preprocess_text'][i])) / data['WORD COUNT'][i],2)

data.head()
# Out:
#                                                 text  \
# 0  Introduction\n\n“If anything kills over 10 mil...
# 1  Human minds, a fascination in itself carrying ...
# 2  Introduction\n\nAI is rapidly evolving in the ...
# 3  “Anything that could give rise to smarter-than...
# 4  “Machine intelligence is the last invention th...
#
#                                                  URL  \
# 0  https://insights.blackcoffer.com/ai-in-healthc...
# 1  https://insights.blackcoffer.com/what-if-the-c...
# 2  https://insights.blackcoffer.com/what-jobs-wil...
# 3  https://insights.blackcoffer.com/will-machine-...
# 4  https://insights.blackcoffer.com/will-ai-repla...
#
#                                      preprocess_text  POSITIVE SCORE  \
# 0  [introduction, kills, people, decades, highly,...             148
# 1  [human, minds, fascination, carrying, potentia...             151
# 2  [introduction, rapidly, evolving, employment, ...             139
# 3  [could, give, rise, smarterthanhuman, intellig...             209
# 4  [machine, intelligence, invention, humanity, m...             169
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  WORD COUNT  \
# 0              34        0.626374            0.456853        1006
# 1              37        0.606383            0.410712         586
# 2              36        0.588571            0.513278         857
# 3              28        0.763713            0.464118         694
# 4              28        0.715736            0.528261         803
#
#    AVG SENTENCE LENGTH  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  \
# 0            13.064935                             13.06                 911
# 1             7.325000                              7.32                 476
# 2            10.082353                             10.08                 783
# 3             7.305263                              7.31                 591
# 4            10.164557                             10.16                 687
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  SYLLABLE PER WORD  \
# 0                     0.905567   5.586227             2583.0
# 1                     0.812287   3.252915             1381.0
# 2                     0.913652   4.397461             2254.0
# 3                     0.851585   3.264634             1652.0
# 4                     0.855542   4.406217             1964.0
#
#    PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                  1             7.60
# 1                  5             7.08
# 2                  2             7.62
# 3                  3             6.97
# 4                  8             7.23

# %%
df = data[['URL','POSITIVE SCORE','NEGATIVE SCORE','POLARITY SCORE','SUBJECTIVITY SCORE','AVG SENTENCE LENGTH','PERCENTAGE OF COMPLEX WORDS','FOG INDEX',
           'AVG NUMBER OF WORDS PER SENTENCE','COMPLEX WORD COUNT','WORD COUNT','SYLLABLE PER WORD','PERSONAL PRONOUNS','AVG WORD LENGTH']]

# %%
df.index = df.index+37

# %%
df.head()
# Out:
#                                                   URL  POSITIVE SCORE  \
# 37  https://insights.blackcoffer.com/ai-in-healthc...             148
# 38  https://insights.blackcoffer.com/what-if-the-c...             151
# 39  https://insights.blackcoffer.com/what-jobs-wil...             139
# 40  https://insights.blackcoffer.com/will-machine-...             209
# 41  https://insights.blackcoffer.com/will-ai-repla...             169
#
#     NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 37              34        0.626374            0.456853            13.064935
# 38              37        0.606383            0.410712             7.325000
# 39              36        0.588571            0.513278            10.082353
# 40              28        0.763713            0.464118             7.305263
# 41              28        0.715736            0.528261            10.164557
#
#     PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 37                     0.905567   5.586227                             13.06
# 38                     0.812287   3.252915                              7.32
# 39                     0.913652   4.397461                             10.08
# 40                     0.851585   3.264634                              7.31
# 41                     0.855542   4.406217                             10.16
#
#     COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 37                 911        1006             2583.0                  1
# 38                 476         586             1381.0                  5
# 39                 783         857             2254.0                  2
# 40                 591         694             1652.0                  3
# 41                 687         803             1964.0                  8
#
#     AVG WORD LENGTH
# 37             7.60
# 38             7.08
# 39             7.62
# 40             6.97
# 41             7.23

# %%
df.to_excel("Output Data Structure.xlsx")
